# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#To read pop_grad data
pop_grad_data_to_load = "pop_grad_data.csv"
pop_grad_data = pd.read_csv(pop_grad_data_to_load)
pop_grad_data=pop_grad_data.rename(columns={"DISTRICT_NAME_left":"City",
                                            "GRAD_RATE":"Graduation_rate"})
pop_grad_data
# Out:
#        dist_year       City            SCHOOL_NAME  YEAR  Graduation_rate  \
# 0  BRIDGETON2016  BRIDGETON  Bridgeton High School  2016            78.78
# 1    CLIFTON2016    CLIFTON    Clifton High School  2016            83.79
# 2    HOBOKEN2016    HOBOKEN    Hoboken High School  2016            86.01
# 3  PRINCETON2016  PRINCETON  Princeton High School  2016            94.85
# 4     SUMMIT2016     SUMMIT     Summit High School  2016            96.09
#
#   DISTRICT_NAME_right      STNAME  Year  Population
# 0           BRIDGETON  New Jersey  2016     24817.0
# 1             CLIFTON  New Jersey  2016     86414.0
# 2             HOBOKEN  New Jersey  2016     55044.0
# 3           PRINCETON  New Jersey  2016     31415.0
# 4              SUMMIT  New Jersey  2016     22238.0

# %%
demo_grad_data = pop_grad_data.set_index(["City"])
demo_grad_data = demo_grad_data.sort_values(by="City", ascending=False)
demo_grad_data
# Out:
#                dist_year            SCHOOL_NAME  YEAR  Graduation_rate  \
# City
# SUMMIT        SUMMIT2016     Summit High School  2016            96.09
# PRINCETON  PRINCETON2016  Princeton High School  2016            94.85
# HOBOKEN      HOBOKEN2016    Hoboken High School  2016            86.01
# CLIFTON      CLIFTON2016    Clifton High School  2016            83.79
# BRIDGETON  BRIDGETON2016  Bridgeton High School  2016            78.78
#
#           DISTRICT_NAME_right      STNAME  Year  Population
# City
# SUMMIT                 SUMMIT  New Jersey  2016     22238.0
# PRINCETON           PRINCETON  New Jersey  2016     31415.0
# HOBOKEN               HOBOKEN  New Jersey  2016     55044.0
# CLIFTON               CLIFTON  New Jersey  2016     86414.0
# BRIDGETON           BRIDGETON  New Jersey  2016     24817.0

# %%
#Ploting Graduation Rate by cities
ax = demo_grad_data.plot.bar(y="Graduation_rate",legend=False)
for i, label in enumerate(list(demo_grad_data.index)):
    ax.annotate("{} %".format(demo_grad_data["Graduation_rate"][i]),(i, 90),ha="left",rotation=45)
plt.ylabel("Graduation_rate %")
plt.title("Graduation Rate")
plt.xticks(rotation=0)
plt.savefig("../graph/GraduationRate_usingAPI")
